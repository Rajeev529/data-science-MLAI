# %%
import pandas as pd
import matplotlib.pyplot as plt
# data=pd.read_csv(r"C:\Users\hp\Downloads\Student_Performance.csv")
data=pd.read_csv(r"C:\Users\hp\Downloads\Student_Performance.csv",nrows=200)
data
# Out:
#      Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                7               99                        Yes            9
# 1                4               82                         No            4
# 2                8               51                        Yes            7
# 3                5               52                        Yes            5
# 4                7               75                         No            8
# ..             ...              ...                        ...          ...
# 195              1               81                        Yes            7
# 196              8               84                         No            5
# 197              7               89                         No            4
# 198              2               55                        Yes            6
# 199              8               93                         No            7
#
#      Sample Question Papers Practiced  Performance Index
# ...

# %%
sample_qpaper=data['Sample Question Papers Practiced']
score=data['Performance Index']
plt.xlabel("sample paper")
plt.ylabel("performance")
plt.scatter(sample_qpaper, score, color='black')

# %%
def grad_dec(m, c, data, l1):
    dm = 0
    dc = 0
    n = len(data)

    for i in range(n):
        x = data.iloc[i]['Sample Question Papers Practiced']
        y = data.iloc[i]['Performance Index']
        dm += (-2/n) * x * (y - (m * x + c))
        dc += (-2/n) * (y - (m * x + c))

    # Update parameters using learning rate l1
    m = m - l1 * dm
    c = c - l1 * dc

    return m, c

# %%
def loss_function(m, c, data):
    error = 0
    n = len(data)
    for i in range(n):
        x = data.iloc[i]['Sample Question Papers Practiced']
        y = data.iloc[i]['Performance Index']
        error += (y - (m * x + c)) ** 2
    return error / n

# %%
import matplotlib.pyplot as plt

# Initial parameters
m = 0
c = 0
l = 0.001
epochs = 1000

# Gradient descent loop
for i in range(epochs):
    if i % 50 == 0:
        print(f"Epoch {i}: Loss = {loss_function(m, c, data):.4f}")
    m, c = grad_dec(m, c, data, l)

# Plotting
sample_qpaper = data['Sample Question Papers Practiced']
score = data['Performance Index']

plt.xlabel("Sample Question Papers Practiced")
plt.ylabel("Performance Index")
plt.scatter(sample_qpaper, score, color='black')

x_axis = list(range(0, 15))
y_axis = [m * x + c for x in x_axis]

plt.plot(x_axis, y_axis, color='red')
plt.show()
# Out:
# Epoch 0: Loss = 3517.3400
# Epoch 50: Loss = 1258.0398
# Epoch 100: Loss = 1197.6111
# Epoch 150: Loss = 1148.6379
# Epoch 200: Loss = 1102.6030
# Epoch 250: Loss = 1059.3022
# Epoch 300: Loss = 1018.5729
# Epoch 350: Loss = 980.2625
# Epoch 400: Loss = 944.2272
# Epoch 450: Loss = 910.3320
# Epoch 500: Loss = 878.4497
# Epoch 550: Loss = 848.4608
# Epoch 600: Loss = 820.2530
# Epoch 650: Loss = 793.7203
# Epoch 700: Loss = 768.7633
# Epoch 750: Loss = 745.2885
# Epoch 800: Loss = 723.2078
# Epoch 850: Loss = 702.4384
# Epoch 900: Loss = 682.9024
# Epoch 950: Loss = 664.5267
