# %% [markdown]
# # one input indipendent variable with one output dependent variable

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv(r"C:\Users\hp\Downloads\Student_Performance.csv", nrows=102)
data
# Out:
#      Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                7               99                        Yes            9
# 1                4               82                         No            4
# 2                8               51                        Yes            7
# 3                5               52                        Yes            5
# 4                7               75                         No            8
# ..             ...              ...                        ...          ...
# 97               6               95                        Yes            6
# 98               3               55                        Yes            5
# 99               1               49                        Yes            9
# 100              3               50                         No            5
# 101              5               70                        Yes            9
#
#      Sample Question Papers Practiced  Performance Index
# ...

# %%
x=data['Hours Studied']
y=data['Previous Scores']

# %%
# visual of linear regresion
import seaborn as sns
sns.lmplot(x='Hours Studied', y='Performance Index', data=data)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(data[['Hours Studied']],data['Performance Index'])
# Out:
# LinearRegression()

# %%
reg.predict([[5],[6]])
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([55.86475433, 59.49125628])

# %%
m=reg.coef_
c=reg.intercept_
c
# Out:
# np.float64(37.73224459863485)

# %%
x=int(input("add a input hour study for prediction: "))
prediction=m*x+c
print(prediction)
# Out:
# add a input hour study for prediction:  8
# [66.74426017]

# %% [markdown]
# # multi input indipendent variable with one output dependent variable

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv(r"C:\Users\hp\Downloads\Student_Performance.csv", nrows=102)
data
# Out:
#      Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                7               99                        Yes            9
# 1                4               82                         No            4
# 2                8               51                        Yes            7
# 3                5               52                        Yes            5
# 4                7               75                         No            8
# ..             ...              ...                        ...          ...
# 97               6               95                        Yes            6
# 98               3               55                        Yes            5
# 99               1               49                        Yes            9
# 100              3               50                         No            5
# 101              5               70                        Yes            9
#
#      Sample Question Papers Practiced  Performance Index
# ...

# %%
m=reg.coef_
c=reg.intercept_

p=int(input("enter hour study: "))
q=int(input("enter prev score: "))
r=int(input("enter ques paper practiced: "))
prediction=m[0]*p+m[1]*q+m[2]*r+c
print("pridicted score: ", prediction)
# Out:
# enter hour study:  8
# enter prev score:  51
# enter ques paper practiced:  2
# pridicted score:  44.33922283433103

# %%
reg=linear_model.LinearRegression()
reg.fit(data[['Hours Studied', 'Previous Scores', 'Sample Question Papers Practiced']], data['Performance Index'])
reg.predict([[8, 51, 2]])
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44.33922283])
