# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.normal(70,10,200) # 200 elements mean 70 and deviation 10 ka sari values almost 70 ke aspass hi regi
plt.hist(x,bins=20,edgecolor='black')

plt.show()

# %%
plt.boxplot(x)
plt.show()
