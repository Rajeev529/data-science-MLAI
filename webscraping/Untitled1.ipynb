# %%
skills = [
    "AI and Machine Learning",
    "Data Science and Analytics",
    "Full-Stack Web Development",
    "Cloud Computing",
    "Cybersecurity",
    "Mobile App Development",
    "Python Programming",
    "Digital Marketing",
    "Content Creation & Copywriting",
    "UX/UI Design",
    "Blogging",
    "Video Content Creation",
    "Graphic Design",
    "Project Management",
    "Financial & Investment Analysis",
    "Sales and Negotiation",
    "Entrepreneurship Development",
    "Adaptability and Resilience",
    "Leadership and Team Building",
    "Problem-Solving and Critical Thinking",
    "Communication and Networking",
    "Financial Literacy"
]

# print(in_demand_skills_india)

# %%
skills_prerequisites = {
    "AI and Machine Learning": [
        "Math fundamentals",
        "Coding basics",
        "Data understanding",
        "Statistical knowledge",
        "Problem decomposition"
    ],
    "Data Science and Analytics": [
        "Statistical thinking",
        "Data manipulation",
        "Programming proficiency",
        "Database knowledge",
        "Analytical mindset"
    ],
    "Full-Stack Web Development": [
        "Frontend basics",
        "Backend logic",
        "Database understanding",
        "Version control",
        "Debugging skills"
    ],
    "Cloud Computing": [
        "Networking basics",
        "Operating systems",
        "Virtualization concepts",
        "Security fundamentals",
        "Scripting ability"
    ],
    "Cybersecurity": [
        "Network fundamentals",
        "OS knowledge",
        "Security principles",
        "Threat awareness",
        "Ethical hacking"
    ],
    "Mobile App Development": [
        "Programming language",
        "UI/UX basics",
        "Platform specific",
        "Testing skills",
        "Deployment knowledge"
    ],
    "Python Programming": [
        "Basic logic",
        "Syntax understanding",
        "Problem solving",
        "Practice coding",
        "Libraries usage"
    ],
    "Digital Marketing": [
        "Internet savvy",
        "Marketing basics",
        "Audience understanding",
        "Analytics interpretation",
        "Content creation"
    ],
    "Content Creation & Copywriting": [
        "Strong writing",
        "Audience research",
        "Grammar accuracy",
        "Creativity spark",
        "Editing proficiency"
    ],
    "UX/UI Design": [
        "Empathy understanding",
        "Design principles",
        "User research",
        "Wireframing skills",
        "Prototyping ability"
    ],
    "Blogging": [
        "Writing passion",
        "Topic knowledge",
        "Audience engagement",
        "Platform familiarity",
        "SEO basics"
    ],
    "Video Content Creation": [
        "Storytelling ability",
        "Filming basics",
        "Editing software",
        "Audio quality",
        "Visual aesthetics"
    ],
    "Graphic Design": [
        "Design principles",
        "Software proficiency",
        "Color theory",
        "Typography knowledge",
        "Creative vision"
    ],
    "Project Management": [
        "Organizational skills",
        "Planning ability",
        "Communication clarity",
        "Risk assessment",
        "Team coordination"
    ],
    "Financial & Investment Analysis": [
        "Math aptitude",
        "Economic concepts",
        "Data interpretation",
        "Financial modeling",
        "Market awareness"
    ],
    "Sales and Negotiation": [
        "Active listening",
        "Persuasion skills",
        "Product knowledge",
        "Objection handling",
        "Relationship building"
    ],
    "Entrepreneurship Development": [
        "Idea generation",
        "Market research",
        "Business planning",
        "Risk tolerance",
        "Networking ability"
    ],
    "Adaptability and Resilience": [
        "Open mind",
        "Problem-solving",
        "Stress management",
        "Learning agility",
        "Positive outlook"
    ],
    "Leadership and Team Building": [
        "Communication skills",
        "Empathy understanding",
        "Delegation ability",
        "Motivation techniques",
        "Conflict resolution"
    ],
    "Problem-Solving and Critical Thinking": [
        "Analytical reasoning",
        "Logical thinking",
        "Information analysis",
        "Solution generation",
        "Decision making"
    ],
    "Communication and Networking": [
        "Active listening",
        "Clear speaking",
        "Written expression",
        "Relationship building",
        "Empathy development"
    ],
    "Financial Literacy": [
        "Basic arithmetic",
        "Budgeting understanding",
        "Saving habits",
        "Debt awareness",
        "Investment basics"
    ]
}

text=input("enter your course: ")
for key, val in skills_prerequisites.items():
    if key==text:
        arr=skills_prerequisites[key]
        for i in arr:
            print(i)
# Out:
# enter your course:  Financial Literacy
# Basic arithmetic
# Budgeting understanding
# Saving habits
# Debt awareness
# Investment basics

# %%
print(skills[6])
print(skill_map[skills[6]])
# Out:
# Python Programming
# ['Basic computer literacy', 'Understanding of programming principles (variables, data types, control flow)', 'Familiarity with data structures and algorithms (basic concepts)', 'Strong communication skills (for collaboration and explaining code)', 'Optional but helpful: Basic knowledge of HTML & CSS (if aiming for web development)']
