# %%
import pandas as pd
rd=pd.read_csv(r"C:\Users\hp\Data Science ML\webscraping\coursera\popularCoursera.csv")
rd
# Out:
#      Unnamed: 0                                            Heading  \
# 0             0                                   IBM Data Science
# 1             1                                   IBM Data Analyst
# 2             2                      IBM Generative AI Engineering
# 3             3                                   IBM AI Developer
# 4             4                       Google Business Intelligence
# ..          ...                                                ...
# 967         967                         Fundamentals of Immunology
# 968         968  Wine Tasting: Sensory Techniques for Wine Anal...
# 969         969     Google Cloud Fundamentals: Core Infrastructure
# 970         970  How to Sell: An Overview of Fundamental Sellin...
# 971         971         Linear Algebra from Elementary to Advanced
#
#            Revewe                                        Description  \
# 0    144K reviews  Skills you'll gain: Dashboard, Data Visualizat...
# ...

# %%
revw=[]
for i in rd['Revewe']:
    s1=""
    for j in i:
        if(j=='K' or j==' '):
            break
        s1+=j
    revw.append(float(s1)*1000)

# %%
revw
# Out:
# [144000.0,
#  93000.0,
#  88000.0,
#  71000.0,
#  3400.0,
#  146000.0,
#  2200.0,
#  113000.0,
#  56000.0,
#  28000.0,
#  61000.0,
#  72000.0,
#  26000.0,
#  49000.0,
#  29000.0,
#  7600.0,
#  99000.0,
#  59000.0,
#  28000.0,
#  48000.0,
#  46000.0,
#  28000.0,
#  59000.0,
#  14000.0,
#  58000.0,
#  101000.0,
#  1400.0,
#  57000.0,
#  95000.0,
#  278000.0,
#  29000.0,
#  17000.0,
#  95000.0,
#  116000.0,
#  24000.0,
#  23000.0,
#  17000.0,
#  13000.0,
#  7400.0,
#  7600.0,
#  7600.0,
#  7500.0,
#  7400.0,
#  14000.0,
#  3800.0,
#  7400.0,
#  7400.0,
#  7400.0,
#  1400.0,
#  7400.0,
#  35000.0,
#  7400.0,
#  11000.0,
#  7400.0,
#  7100.0,
#  7300.0,
#  7400.0,
#  7300.0,
#  7300.0,
#  7300.0,
#  5700.0,
#  7300.0,
#  7300.0,
#  7300.0,
#  7300.0,
#  6400.0,
#  6600.0,
#  9400.0,
#  31000.0,
#  7300.0,
#  22000.0,
#  20000.0,
#  590000.0,
#  3400.0,
#  8700.0,
#  2800.0,
#  7500.0,
#  13000.0,
#  160000.0,
#  6600.0,
#  28000.0,
#  9700.0,
#  6300.0,
#  6600.0,
#  6700.0,
#  5500.0,
# ...
