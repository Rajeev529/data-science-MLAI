# %%
import pandas as pd

# %%
var=pd.read_excel(r'C:\Users\hp\Downloads\practice files\storeRaw.xlsx')
var.isnull().sum()
# Out:
# Lookup Table 1              2091
# Unnamed: 1                  2091
# Unnamed: 2                  2102
# Order ID                       0
# Order Date                     0
# Order Priority                 0
# Order Quantity                 0
# Order Type                  2101
# Expanded Order Type         2102
# Sales                          0
# Discount                    2102
# Sales with Discount         2102
# Sales with Free Shipping    2102
# Ship Mode                      0
# Shipping Cost                  0
# dtype: int64

# %% [markdown]
# # drop axis=0 along horizontal axis=1 drop along vertical

# %%
var.dropna(axis=1)
# Out:
#       Order ID Order Date Order Priority  Order Quantity    Sales  \
# 0        51648 2012-01-01            Low              45  2354.80
# 1        51648 2012-01-01            Low              50   187.88
# 2        29030 2012-01-02         Medium              10   192.58
# 3        54214 2012-01-02         Medium              38  7325.63
# 4        47591 2012-01-02       Critical              27   279.40
# ...        ...        ...            ...             ...      ...
# 2097     49344 2012-12-30            Low              31   672.93
# 2098     25542 2012-12-30            Low              37   257.46
# 2099     50950 2012-12-30  Not Specified              35   448.10
# 2100     45127 2012-12-30         Medium              10    14.15
# 2101     47815 2012-12-30  Not Specified              45   580.96
#
#         Ship Mode  Shipping Cost
# 0     Regular Air          19.99
# 1     Regular Air           2.97
# 2     Regular Air           4.10
# 3     Express Air          24.49
# ...

# %%
var.dropna(how='any',axis=1)  #drop all row where a single value NAN appear in row
# Out:
#       Order ID Order Date Order Priority  Order Quantity    Sales  \
# 0        51648 2012-01-01            Low              45  2354.80
# 1        51648 2012-01-01            Low              50   187.88
# 2        29030 2012-01-02         Medium              10   192.58
# 3        54214 2012-01-02         Medium              38  7325.63
# 4        47591 2012-01-02       Critical              27   279.40
# ...        ...        ...            ...             ...      ...
# 2097     49344 2012-12-30            Low              31   672.93
# 2098     25542 2012-12-30            Low              37   257.46
# 2099     50950 2012-12-30  Not Specified              35   448.10
# 2100     45127 2012-12-30         Medium              10    14.15
# 2101     47815 2012-12-30  Not Specified              45   580.96
#
#         Ship Mode  Shipping Cost
# 0     Regular Air          19.99
# 1     Regular Air           2.97
# 2     Regular Air           4.10
# 3     Express Air          24.49
# ...

# %%
var.dropna(how="all")
# Out:
#       Lookup Table 1    Unnamed: 1  Unnamed: 2  Order ID Order Date  \
# 0     Order Quantity          Type         NaN     51648 2012-01-01
# 1                  1          Mini         NaN     51648 2012-01-01
# 2                  6   Extra Small         NaN     29030 2012-01-02
# 3                 11         Small         NaN     54214 2012-01-02
# 4                 16  Small-Medium         NaN     47591 2012-01-02
# ...              ...           ...         ...       ...        ...
# 2097             NaN           NaN         NaN     49344 2012-12-30
# 2098             NaN           NaN         NaN     25542 2012-12-30
# 2099             NaN           NaN         NaN     50950 2012-12-30
# 2100             NaN           NaN         NaN     45127 2012-12-30
# 2101             NaN           NaN         NaN     47815 2012-12-30
#
#      Order Priority  Order Quantity Order Type  Expanded Order Type    Sales  \
# ...

# %%
var.dropna(subset=["Discount"])
# Out:
# Empty DataFrame
# Columns: [Lookup Table 1, Unnamed: 1, Unnamed: 2, Order ID, Order Date, Order Priority, Order Quantity, Order Type, Expanded Order Type, Sales, Discount, Sales with Discount, Sales with Free Shipping, Ship Mode, Shipping Cost]
# Index: []

# %%
var.dropna(inplace=True,axis=1)
var
# Out:
#       Order ID Order Date Order Priority  Order Quantity    Sales  \
# 0        51648 2012-01-01            Low              45  2354.80
# 1        51648 2012-01-01            Low              50   187.88
# 2        29030 2012-01-02         Medium              10   192.58
# 3        54214 2012-01-02         Medium              38  7325.63
# 4        47591 2012-01-02       Critical              27   279.40
# ...        ...        ...            ...             ...      ...
# 2097     49344 2012-12-30            Low              31   672.93
# 2098     25542 2012-12-30            Low              37   257.46
# 2099     50950 2012-12-30  Not Specified              35   448.10
# 2100     45127 2012-12-30         Medium              10    14.15
# 2101     47815 2012-12-30  Not Specified              45   580.96
#
#         Ship Mode  Shipping Cost
# 0     Regular Air          19.99
# 1     Regular Air           2.97
# 2     Regular Air           4.10
# 3     Express Air          24.49
# ...

# %%
dataset={"product":['a','b','c','d'],"price":[70,80,90,100],"dicount":['80%','NAN','30%','NAN']}
var1=pd.DataFrame(dataset)
var1
# Out:
#   product  price dicount
# 0       a     70     80%
# 1       b     80     NAN
# 2       c     90     30%
# 3       d    100     NAN

# %%
var1.dropna(subset=['dicount'])
# Out:
#   product  price dicount
# 0       a     70     80%
# 2       c     90     30%

# %%
var1.dropna(axis=1,thresh=1)
# Out:
#   product  price dicount
# 0       a     70     80%
# 1       b     80    None
# 2       c     90     30%
# 3       d    100    None

# %%
var1.fillna({"discount":2})
var1
# Out:
#   product  price dicount
# 0       a     70     80%
# 1       b     80     NAN
# 2       c     90     30%
# 3       d    100     NAN

# %%
var=pd.read_excel(r'C:\\Users\\hp\\Downloads\\practice files\\storeRaw.xlsx')
val1=var["Sales"]
val2=var["Shipping Cost"]
Discount=(val1+val2)/10
var.fillna({"Discount":Discount})
# Out:
#       Lookup Table 1    Unnamed: 1  Unnamed: 2  Order ID Order Date  \
# 0     Order Quantity          Type         NaN     51648 2012-01-01
# 1                  1          Mini         NaN     51648 2012-01-01
# 2                  6   Extra Small         NaN     29030 2012-01-02
# 3                 11         Small         NaN     54214 2012-01-02
# 4                 16  Small-Medium         NaN     47591 2012-01-02
# ...              ...           ...         ...       ...        ...
# 2097             NaN           NaN         NaN     49344 2012-12-30
# 2098             NaN           NaN         NaN     25542 2012-12-30
# 2099             NaN           NaN         NaN     50950 2012-12-30
# 2100             NaN           NaN         NaN     45127 2012-12-30
# 2101             NaN           NaN         NaN     47815 2012-12-30
#
#      Order Priority  Order Quantity Order Type  Expanded Order Type    Sales  \
# ...

# %%
# var.fillna(method="ffill") fill forward line data
# var.fillna(method="bfill") fill backward line data
# var.fillna(method="bfill", axis=1) fill backward line data along vertical
# var.fillna(method="ffill", axis=1) fill forward line data along vertical

# %%
var.fillna("python",limit=2)
# Out:
#       Lookup Table 1    Unnamed: 1 Unnamed: 2  Order ID Order Date  \
# 0     Order Quantity          Type     python     51648 2012-01-01
# 1                  1          Mini     python     51648 2012-01-01
# 2                  6   Extra Small        NaN     29030 2012-01-02
# 3                 11         Small        NaN     54214 2012-01-02
# 4                 16  Small-Medium        NaN     47591 2012-01-02
# ...              ...           ...        ...       ...        ...
# 2097             NaN           NaN        NaN     49344 2012-12-30
# 2098             NaN           NaN        NaN     25542 2012-12-30
# 2099             NaN           NaN        NaN     50950 2012-12-30
# 2100             NaN           NaN        NaN     45127 2012-12-30
# 2101             NaN           NaN        NaN     47815 2012-12-30
#
#      Order Priority  Order Quantity Order Type Expanded Order Type    Sales  \
# 0               Low              45      Large              python  2354.80
# ...

# %%
bvar[1:3]
block.fillna("will filled")
var
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10948\3689460657.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   block.fillna("will filled")
#       Lookup Table 1    Unnamed: 1  Unnamed: 2  Order ID Order Date  \
# 0     Order Quantity          Type         NaN     51648 2012-01-01
# 1                  1          Mini         NaN     51648 2012-01-01
# 2                  6   Extra Small         NaN     29030 2012-01-02
# 3                 11         Small         NaN     54214 2012-01-02
# 4                 16  Small-Medium         NaN     47591 2012-01-02
# ...              ...           ...         ...       ...        ...
# 2097             NaN           NaN         NaN     49344 2012-12-30
# 2098             NaN           NaN         NaN     25542 2012-12-30
# ...
