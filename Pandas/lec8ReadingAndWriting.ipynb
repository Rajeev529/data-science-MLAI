# %%
import pandas as pd

# %%
csvfile=pd.read_excel(r"C:\Users\hp\Downloads\practice files\SaleData.xlsx")
csvfile
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %% [markdown]
# # to get AP parameteres use csvfile.index

# %%
csvfile.index
# Out:
# RangeIndex(start=0, stop=45, step=1)

# %%
csvfile.columns
# Out:
# Index(['OrderDate', 'Region', 'Manager', 'SalesMan', 'Item', 'Units',
#        'Unit_price', 'Sale_amt'],
#       dtype='object')

# %% [markdown]
# # it decribe statitics data .describe() for analyze int values

# %%
NT=csvfile.describe()
NT
# Out:
#                  OrderDate       Units   Unit_price       Sale_amt
# count                   43   45.000000    45.000000      45.000000
# mean   2018-12-29 00:00:00   54.083333   583.313889   30578.761111
# min    2018-01-06 00:00:00    2.000000    58.500000     250.000000
# 25%    2018-07-03 12:00:00   28.000000   225.000000    4329.000000
# 50%    2018-12-29 00:00:00   53.000000   500.000000   17100.000000
# 75%    2019-06-25 12:00:00   75.000000  1198.000000   43128.000000
# max    2019-12-21 00:00:00  278.000000  1198.000000  113810.000000
# std                    NaN   45.096676   444.806622   32227.534943

# %%
units=NT['Units']

print('total row: ',units['count'])

print('mean of the unit: ',units['mean'])

print('maximum: ',units['max'])
# Out:
# total row:  45.0
# mean of the unit:  54.083333333333336
# maximum:  278.0

# %% [markdown]
# # head(x) get data till x row and tail(x) from bottom

# %%
csvfile.head(4)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0

# %%
csvfile.tail(3)
# Out:
#     OrderDate   Region Manager SalesMan          Item   Units  Unit_price  \
# 42 2019-12-21  Central  Martha   Steven  Home Theater   28.00     500.000
# 43        NaT      NaN     NaN      NaN           NaN  278.00    1125.000
# 44        NaT      NaN     NaN      NaN           NaN   34.75     140.625
#
#     Sale_amt
# 42  14000.00
# 43  62550.00
# 44   7818.75

# %% [markdown]
# # using slicing of file

# %%
csvfile[:3]
csvfile[4:10]
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 4 2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
# 5 2018-04-01     East   Martha  Alexander  Home Theater   60.0       500.0
# 6 2018-04-18  Central   Martha     Steven    Television   75.0      1198.0
# 7 2018-05-05  Central  Hermann       Luis    Television   90.0      1198.0
# 8 2018-05-22     West  Douglas    Michael    Television   32.0      1198.0
# 9 2018-06-08     East   Martha  Alexander  Home Theater   60.0       500.0
#
#    Sale_amt
# 4   67088.0
# 5   30000.0
# 6   89850.0
# 7  107820.0
# 8   38336.0
# 9   30000.0

# %%
csvfile.index.array
# Out:
# <NumpyExtensionArray>
# [ np.int64(0),  np.int64(1),  np.int64(2),  np.int64(3),  np.int64(4),
#   np.int64(5),  np.int64(6),  np.int64(7),  np.int64(8),  np.int64(9),
#  np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14),
#  np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19),
#  np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24),
#  np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29),
#  np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34),
#  np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39),
#  np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44)]
# Length: 45, dtype: int64

# %% [markdown]
# # give to a 2d array in numpy format

# %%
csvfile.to_numpy()
# Out:
# array([[Timestamp('2018-01-06 00:00:00'), 'East', 'Martha', 'Alexander',
#         'Television', 95.0, 1198.0, 113810.0],
#        [Timestamp('2018-01-23 00:00:00'), 'Central', 'Hermann', 'Shelli',
#         'Home Theater', 50.0, 500.0, 25000.0],
#        [Timestamp('2018-02-09 00:00:00'), 'Central', 'Hermann', 'Luis',
#         'Television', 36.0, 1198.0, 43128.0],
#        [Timestamp('2018-02-26 00:00:00'), 'Central', 'Timothy', 'David',
#         'Cell Phone', 27.0, 225.0, 6075.0],
#        [Timestamp('2018-03-15 00:00:00'), 'West', 'Timothy', 'Stephen',
#         'Television', 56.0, 1198.0, 67088.0],
#        [Timestamp('2018-04-01 00:00:00'), 'East', 'Martha', 'Alexander',
#         'Home Theater', 60.0, 500.0, 30000.0],
#        [Timestamp('2018-04-18 00:00:00'), 'Central', 'Martha', 'Steven',
#         'Television', 75.0, 1198.0, 89850.0],
#        [Timestamp('2018-05-05 00:00:00'), 'Central', 'Hermann', 'Luis',
#         'Television', 90.0, 1198.0, 107820.0],
# ...

# %% [markdown]
# # acending and descending sort(axis=0,1, ascending=true/false)

# %%
csvfile.sort_index(axis=0,ascending=False)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 44        NaT      NaN      NaN        NaN           NaN   34.75     140.625
# 43        NaT      NaN      NaN        NaN           NaN  278.00    1125.000
# 42 2019-12-21  Central   Martha     Steven  Home Theater   28.00     500.000
# 41 2019-12-04  Central  Hermann       Luis  Home Theater   94.00     500.000
# 40 2019-11-17  Central  Hermann       Luis  Home Theater   11.00     500.000
# 39 2019-10-31  Central   Martha     Steven    Television   14.00    1198.000
# 38 2019-10-14     West  Douglas    Michael  Home Theater   57.00     500.000
# 37 2019-09-27     West  Timothy    Stephen    Cell Phone   76.00     225.000
# 36 2019-09-10  Central  Timothy      David    Television    7.00    1198.000
# 35 2019-08-24     West  Timothy    Stephen          Desk    3.00     125.000
# 34 2019-08-07  Central  Hermann     Shelli   Video Games   42.00      58.500
# ...

# %% [markdown]
# # to change values in the data loc[row,column]

# %%
csvfile.loc[0,"Region"]="outside"
csvfile
# Out:
#     OrderDate    Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06   outside   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  gurugram  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  hariyana  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26    gujrat  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15      West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01      East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18   Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05   Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22      West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08      East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25   Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
csvfile.loc[0,"Region"]="outside"
n=csvfile.index.stop/9
z=int(n)
for i in range(0,z):
    change=input("changes write here: ")
    csvfile.loc[i,"Region"]=change
csvfile
# Out:
# changes write here:  delhi
# changes write here:  bihar

# %% [markdown]
# # to get long data according to user loc[[1,2,3,4...],["col1","col2"...]]

# %%
csvfile.loc[[1,2,3],["Item","SalesMan"]]
# Out:
#            Item SalesMan
# 1  Home Theater   Shelli
# 2    Television     Luis
# 3    Cell Phone    David

# %%
csvfile[["Item","SalesMan"]]
# Out:
#             Item   SalesMan
# 0     Television  Alexander
# 1   Home Theater     Shelli
# 2     Television       Luis
# 3     Cell Phone      David
# 4     Television    Stephen
# 5   Home Theater  Alexander
# 6     Television     Steven
# 7     Television       Luis
# 8     Television    Michael
# 9   Home Theater  Alexander
# 10    Television      Sigal
# 11  Home Theater      Diana
# 12  Home Theater      Karen
# 13    Television  Alexander
# 14          Desk       John
# 15   Video Games  Alexander
# 16  Home Theater      Sigal
# 17    Cell Phone  Alexander
# 18    Cell Phone      Karen
# 19   Video Games     Shelli
# 20    Television       John
# 21   Video Games      Karen
# 22  Home Theater      David
# 23  Home Theater       John
# 24  Home Theater  Alexander
# 25  Home Theater    Stephen
# 26   Video Games       Luis
# 27    Television     Steven
# 28    Cell Phone      Diana
# 29    Television      David
# 30  Home Theater      David
# 31          Desk     Shelli
# ...

# %%
csvfile.loc[[1,2,3,8],:]
# Out:
#    OrderDate   Region  Manager SalesMan          Item  Units  Unit_price  \
# 1 2018-01-23  Central  Hermann   Shelli  Home Theater   50.0       500.0
# 2 2018-02-09  Central  Hermann     Luis    Television   36.0      1198.0
# 3 2018-02-26  Central  Timothy    David    Cell Phone   27.0       225.0
# 8 2018-05-22     West  Douglas  Michael    Television   32.0      1198.0
#
#    Sale_amt (0, Region)
# 1   25000.0     outside
# 2   43128.0     outside
# 3    6075.0     outside
# 8   38336.0     outside

# %%
csvfile.drop([1,2,3],axis=0)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06  outside   Martha  Alexander    Television   95.00    1198.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.00     500.000
# 12 2018-07-29     East  Douglas      Karen  Home Theater   81.00     500.000
# 13 2018-08-15     East   Martha  Alexander    Television   35.00    1198.000
# ...
