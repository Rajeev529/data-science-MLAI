# %%
import pandas as pd

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx")
dataset
# Out:
#       Lookup Table 1    Unnamed: 1  Unnamed: 2  Order ID Order Date  \
# 0     Order Quantity          Type         NaN     51648 2012-01-01
# 1                  1          Mini         NaN     51648 2012-01-01
# 2                  6   Extra Small         NaN     29030 2012-01-02
# 3                 11         Small         NaN     54214 2012-01-02
# 4                 16  Small-Medium         NaN     47591 2012-01-02
# ...              ...           ...         ...       ...        ...
# 2097             NaN           NaN         NaN     49344 2012-12-30
# 2098             NaN           NaN         NaN     25542 2012-12-30
# 2099             NaN           NaN         NaN     50950 2012-12-30
# 2100             NaN           NaN         NaN     45127 2012-12-30
# 2101             NaN           NaN         NaN     47815 2012-12-30
#
#      Order Priority  Order Quantity Order Type  Expanded Order Type    Sales  \
# ...

# %% [markdown]
# # fetch data till perticular row 'nrows'

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",nrows=3)
# dataset.isnull().sum()
dataset
# Out:
#    Lookup Table 1   Unnamed: 1  Unnamed: 2  Order ID Order Date  \
# 0  Order Quantity         Type         NaN     51648 2012-01-01
# 1               1         Mini         NaN     51648 2012-01-01
# 2               6  Extra Small         NaN     29030 2012-01-02
#
#   Order Priority  Order Quantity Order Type  Expanded Order Type    Sales  \
# 0            Low              45      Large                  NaN  2354.80
# 1            Low              50        NaN                  NaN   187.88
# 2         Medium              10        NaN                  NaN   192.58
#
#    Discount  Sales with Discount  Sales with Free Shipping    Ship Mode  \
# 0       NaN                  NaN                       NaN  Regular Air
# 1       NaN                  NaN                       NaN  Regular Air
# 2       NaN                  NaN                       NaN  Regular Air
#
#    Shipping Cost
# 0          19.99
# 1           2.97
# 2           4.10

# %% [markdown]
# # 'usecols' to get perticular columns

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",nrows=5,usecols=["Sales","Discount"])
dataset
# Out:
#      Sales  Discount
# 0  2354.80       NaN
# 1   187.88       NaN
# 2   192.58       NaN
# 3  7325.63       NaN
# 4   279.40       NaN

# %%
#practical approch
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",nrows=5,usecols=[0,4])
dataset.insert(2,"products",["fruits","mango","apple","guava","pine"])
print(dataset)
dataset.to_csv('updated.csv',index=False)
# Out:
#    Lookup Table 1 Order Date products
# 0  Order Quantity 2012-01-01   fruits
# 1               1 2012-01-01    mango
# 2               6 2012-01-02    apple
# 3              11 2012-01-02    guava
# 4              16 2012-01-02     pine

# %% [markdown]
# # change header by data header=int

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",header=1,nrows=3)
dataset
# Out:
#    Order Quantity         Type  Unnamed: 2  51648 2012-01-01 00:00:00     Low  \
# 0               1         Mini         NaN  51648          2012-01-01     Low
# 1               6  Extra Small         NaN  29030          2012-01-02  Medium
# 2              11        Small         NaN  54214          2012-01-02  Medium
#
#    45  Large  Unnamed: 8   2354.8  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0  50    NaN         NaN   187.88          NaN          NaN          NaN
# 1  10    NaN         NaN   192.58          NaN          NaN          NaN
# 2  38    NaN         NaN  7325.63          NaN          NaN          NaN
#
#    Regular Air  19.99
# 0  Regular Air   2.97
# 1  Regular Air   4.10
# 2  Express Air  24.49

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",nrows=3,names=["col1","col2","col3","col4"])
dataset
# Out:
#                                                                                  col1  \
# Order Quantity Type        NaN 51648 2012-01-01 Low    45 Large NaN 2354.80 NaN   NaN
# 1              Mini        NaN 51648 2012-01-01 Low    50 NaN   NaN 187.88  NaN   NaN
# 6              Extra Small NaN 29030 2012-01-02 Medium 10 NaN   NaN 192.58  NaN   NaN
#
#                                                                                  col2  \
# Order Quantity Type        NaN 51648 2012-01-01 Low    45 Large NaN 2354.80 NaN   NaN
# 1              Mini        NaN 51648 2012-01-01 Low    50 NaN   NaN 187.88  NaN   NaN
# 6              Extra Small NaN 29030 2012-01-02 Medium 10 NaN   NaN 192.58  NaN   NaN
#
#                                                                                         col3  \
# Order Quantity Type        NaN 51648 2012-01-01 Low    45 Large NaN 2354.80 NaN  Regular Air
# ...

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",nrows=3,header=None)
dataset
# Out:
#                0     1   2         3                    4               5   \
# 0  Lookup Table 1   NaN NaN  Order ID           Order Date  Order Priority
# 1  Order Quantity  Type NaN     51648  2012-01-01 00:00:00             Low
# 2               1  Mini NaN     51648  2012-01-01 00:00:00             Low
#
#                6           7                    8       9         10  \
# 0  Order Quantity  Order Type  Expanded Order Type   Sales  Discount
# 1              45       Large                  NaN  2354.8       NaN
# 2              50         NaN                  NaN  187.88       NaN
#
#                     11                        12           13             14
# 0  Sales with Discount  Sales with Free Shipping    Ship Mode  Shipping Cost
# 1                  NaN                       NaN  Regular Air          19.99
# 2                  NaN                       NaN  Regular Air           2.97

# %% [markdown]
# # change dtype of rows

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",nrows=3, dtype={"Order Quantity":"float","Sales":"string"})
dataset
# Out:
#    Lookup Table 1   Unnamed: 1  Unnamed: 2  Order ID Order Date  \
# 0  Order Quantity         Type         NaN     51648 2012-01-01
# 1               1         Mini         NaN     51648 2012-01-01
# 2               6  Extra Small         NaN     29030 2012-01-02
#
#   Order Priority  Order Quantity Order Type  Expanded Order Type   Sales  \
# 0            Low            45.0      Large                  NaN  2354.8
# 1            Low            50.0        NaN                  NaN  187.88
# 2         Medium            10.0        NaN                  NaN  192.58
#
#    Discount  Sales with Discount  Sales with Free Shipping    Ship Mode  \
# 0       NaN                  NaN                       NaN  Regular Air
# 1       NaN                  NaN                       NaN  Regular Air
# 2       NaN                  NaN                       NaN  Regular Air
#
#    Shipping Cost
# 0          19.99
# 1           2.97
# 2           4.10

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",nrows=3)
val=dataset.select_dtypes(include="datetime")
print(val)
# Out:
#   Order Date
# 0 2012-01-01
# 1 2012-01-01
# 2 2012-01-02

# %%
dataset=pd.read_excel(r"C:\Users\hp\Downloads\practice files\storeRaw.xlsx",nrows=10,usecols=["Shipping Cost"],dtype={"Shipping Cost":"float"})
i=0
data=dataset["Shipping Cost"]
while(True):
    print(data[i])
    i=i+1
# Out:
# 19.99
# 2.97
# 4.1
# 24.49
# 6.91
# 13.99
# 8.99
# 0.7
# 14.0
# 4.28
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 10 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 5
#       3 data=dataset["Shipping Cost"]
#       4 while(True):
# ----> 5     print(data[i])
#       6     i=i+1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# ...
