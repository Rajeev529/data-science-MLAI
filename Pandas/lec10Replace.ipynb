# %%
import pandas as pd

# %%
var=pd.read_excel(r'C:\Users\hp\Downloads\SaleData.xlsx')
var
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00
# 1         NaT  Central      NaN     Shelli  Home Theater   50.00
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00
# 3  2018-02-26  Central  Timothy      David    Cell Phone     NaN
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00
# 6  2018-04-18  Central   Martha     Steven    Television   75.00
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00
# 8  2018-05-22     West  Douglas    Michael    Television   32.00
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00
# 10        NaT  Central  Hermann      Sigal    Television   90.00
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.00
# 12 2018-07-29     East  Douglas        NaN  Home Theater   81.00
# ...

# %%
var.replace(to_replace=1198,value=1000)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00
# 1         NaT  Central      NaN     Shelli  Home Theater   50.00
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00
# 3  2018-02-26  Central  Timothy      David    Cell Phone     NaN
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00
# 6  2018-04-18  Central   Martha     Steven    Television   75.00
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00
# 8  2018-05-22     West  Douglas    Michael    Television   32.00
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00
# 10        NaT  Central  Hermann      Sigal    Television   90.00
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.00
# 12 2018-07-29     East  Douglas        NaN  Home Theater   81.00
# ...

# %%
var.replace(to_replace='Television',value="LCD")
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  \
# 0  2018-01-06     East   Martha  Alexander           LCD   95.00
# 1         NaT  Central      NaN     Shelli  Home Theater   50.00
# 2  2018-02-09  Central  Hermann       Luis           LCD   36.00
# 3  2018-02-26  Central  Timothy      David    Cell Phone     NaN
# 4  2018-03-15     West  Timothy    Stephen           LCD   56.00
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00
# 6  2018-04-18  Central   Martha     Steven           LCD   75.00
# 7  2018-05-05  Central  Hermann       Luis           LCD   90.00
# 8  2018-05-22     West  Douglas    Michael           LCD   32.00
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00
# 10        NaT  Central  Hermann      Sigal           LCD   90.00
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.00
# 12 2018-07-29     East  Douglas        NaN  Home Theater   81.00
# ...

# %%
var.replace(['Luis','Alexander'],'Mohan Ranga')
# Out:
#     OrderDate   Region  Manager     SalesMan          Item   Units  \
# 0  2018-01-06     East   Martha  Mohan Ranga    Television   95.00
# 1         NaT  Central      NaN       Shelli  Home Theater   50.00
# 2  2018-02-09  Central  Hermann  Mohan Ranga    Television   36.00
# 3  2018-02-26  Central  Timothy        David    Cell Phone     NaN
# 4  2018-03-15     West  Timothy      Stephen    Television   56.00
# 5  2018-04-01     East   Martha  Mohan Ranga  Home Theater   60.00
# 6  2018-04-18  Central   Martha       Steven    Television   75.00
# 7  2018-05-05  Central  Hermann  Mohan Ranga    Television   90.00
# 8  2018-05-22     West  Douglas      Michael    Television   32.00
# 9  2018-06-08     East   Martha  Mohan Ranga  Home Theater   60.00
# 10        NaT  Central  Hermann        Sigal    Television   90.00
# 11 2018-07-12     East   Martha        Diana  Home Theater   29.00
# 12 2018-07-29     East  Douglas          NaN  Home Theater   81.00
# ...

# %%
var.replace({"Manager":'[A-Za-z]'},0,regex=True)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  \
# 0  2018-01-06     East      0.0  Alexander    Television   95.00
# 1         NaT  Central      NaN     Shelli  Home Theater   50.00
# 2  2018-02-09  Central      0.0       Luis    Television   36.00
# 3  2018-02-26  Central      0.0      David    Cell Phone     NaN
# 4  2018-03-15     West      0.0    Stephen    Television   56.00
# 5  2018-04-01     East      0.0  Alexander  Home Theater   60.00
# 6  2018-04-18  Central      0.0     Steven    Television   75.00
# 7  2018-05-05  Central      0.0       Luis    Television   90.00
# 8  2018-05-22     West      0.0    Michael    Television   32.00
# 9  2018-06-08     East      0.0  Alexander  Home Theater   60.00
# 10        NaT  Central      0.0      Sigal    Television   90.00
# 11 2018-07-12     East      0.0      Diana  Home Theater   29.00
# 12 2018-07-29     East      0.0        NaN  Home Theater   81.00
# ...

# %%
var.replace(1198,method='ffill',limit=2)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3296\4258843700.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var.replace(1198,method='ffill',limit=2)
#     OrderDate   Region  Manager   SalesMan          Item   Units  \
# 0  2018-01-06     East      0.0  Alexander    Television   95.00
# 1         NaT  Central      NaN     Shelli  Home Theater   50.00
# 2  2018-02-09  Central      0.0       Luis    Television   36.00
# 3  2018-02-26  Central      0.0      David    Cell Phone     NaN
# 4  2018-03-15     West      0.0    Stephen    Television   56.00
# 5  2018-04-01     East      0.0  Alexander  Home Theater   60.00
# 6  2018-04-18  Central      0.0     Steven    Television   75.00
# 7  2018-05-05  Central      0.0       Luis    Television   90.00
# 8  2018-05-22     West      0.0    Michael    Television   32.00
# 9  2018-06-08     East      0.0  Alexander  Home Theater   60.00
# ...

# %% [markdown]
# # interpolate

# %%
val=pd.read_excel(r'C:\Users\hp\Downloads\SaleData.xlsx')
val
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00
# 1         NaT  Central      NaN     Shelli  Home Theater   50.00
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00
# 3  2018-02-26  Central  Timothy      David    Cell Phone     NaN
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00
# 6  2018-04-18  Central   Martha     Steven    Television   75.00
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00
# 8  2018-05-22     West  Douglas    Michael    Television   32.00
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00
# 10        NaT  Central  Hermann      Sigal    Television   90.00
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.00
# 12 2018-07-29     East  Douglas        NaN  Home Theater   81.00
# ...

# %%
val.interpolate(mathod='linear')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10380\3089898889.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   val.interpolate(mathod='linear')
#     OrderDate   Region  Manager   SalesMan          Item   Units  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00
# 1  2018-01-23  Central      NaN     Shelli  Home Theater   50.00
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00
# 3  2018-02-26  Central  Timothy      David    Cell Phone   46.00
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00
# 6  2018-04-18  Central   Martha     Steven    Television   75.00
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00
# 8  2018-05-22     West  Douglas    Michael    Television   32.00
# ...

# %%
val.interpolate() #fill data auto by lookig sequence
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10380\2069349831.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   val.interpolate() #fill data auto by lookig sequence
#     OrderDate   Region  Manager   SalesMan          Item   Units  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00
# 1  2018-01-23  Central      NaN     Shelli  Home Theater   50.00
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00
# 3  2018-02-26  Central  Timothy      David    Cell Phone   46.00
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00
# 6  2018-04-18  Central   Martha     Steven    Television   75.00
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00
# 8  2018-05-22     West  Douglas    Michael    Television   32.00
# ...
